# %% [markdown]
# # Chapter 2: Variables and Simple Data Types

# %% [markdown]
# In this chapter, we will discuss the different data types we can work with in the Python language. We will also see how to use variables to represent data in our programs.

# %% [markdown]
# ## 2.1 Hello WORD!

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# When we run a cell in Jupyter (by pressing Shift+Enter or clicking the run button), we instruct the Python interpreter to execute the code in that cell. The interpreter processes each statement in the source code, attempting to understand and carry out its instructions. By using the `print()` function, we invoke a built-in Python function that outputs to the screen whatever is enclosed within the parentheses.
