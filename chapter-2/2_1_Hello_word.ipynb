# %% [markdown]
# # Chapter 2: Variables and Simple Data Types

# %% [markdown]
# This notebook covers the very first step in programming: running a line of code to see an output. We will use Python's `print()` function to display a "Hello World!" message, a classic tradition for programmers.

# %% [markdown]
# ## 2.1) Hello World!

# %% [markdown]
# Traditionally, the first program you write when learning a new language is one that prints "Hello World!" to the screen. This simple exercise confirms that your environment is set up correctly and introduces you to a fundamental command.

# %%
print("Hello World!")

# %% [markdown]
# When we run this cell, we are using the built-in `print()` function. This function instructs Python to display whatever is inside the parentheses as output. In this case, it displays the text (or "string") "Hello World!".
