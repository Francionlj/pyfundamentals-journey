# %% [markdown]
# # Chapter 2: Variables and Simple Data Types

# %% [markdown]
# This notebook introduces the **Zen of Python**, the set of guiding principles that shape the design and philosophy of the Python language.

# %% [markdown]
# ## 2.6) The Zen of Python

# %% [markdown]
# The "Zen of Python" is a collection of 19 guiding principles for writing computer programs that influence the design of the Python language. Authored by Tim Peters, you can access them anytime by running `import this`.
#
# A **module** is a file containing Python code that you can bring into your program. To use a module, you write `import` followed by the module's name.

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# These principles, such as "Beautiful is better than ugly" and "Readability counts," are good ideas to keep in mind as you write your own code. They encourage you to write programs that are not only functional but also clean, readable, and easy to maintain. There's no need to memorize them, but you will see them reflected in the code of experienced Python programmers.
