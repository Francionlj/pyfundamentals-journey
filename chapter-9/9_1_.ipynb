# %% [markdown]
# # Chapter 9: Classes

# %% [markdown]
# A programacao orientada o objetos (POO) e uma das abordagens mais eficases no que se diz respeito a desenvolvimento de sftowere. No POO escrevemos uma classe que representa coisas e situacoes do mundo cotidioano e criamos objetos tomando como base classes. Ao escrever uma classe definimos o comportamento geral que uma categoria pode ter.
#
# Ao criarmos um objeto individual a partir de uma classe cada objeto e automaticamente complementado com o comportamento geral; assim podemos atribuir qualquer carcteristicas especificas que quisermos.
#
# A criacao de um objeto a partir de uma classe se chama instaciacao e ttabalhamos com uma isntaciacao de uma classe. Neste capiyulo vamos apremder como criamos uma classe e suas instacias. excreveremos tambem classes que incrementam a funcionalidade das classes exixtentes para que classes existentes e semalhantes possao compartilhar funcionalidades em comum que possamos fazer mais com menos codigo. Vamos armazenar c;asses em modulos e vamos importar classes desemvolvidas por outros programadores em nosso arquivo de progrma.

# %% [markdown]
# ## 9.1) Criando e usando uma classe

# %% [markdown]
# e possivel modelar quase qualquer coisa com um classe. Vamos comecar criando uma classe simples chamada `cachoro` nao um cachore especifico um bem generico. O que sabenos sobre um cachoro de estimacao, eles tem um nome e uma diade. que eles podem semtar e rolar. entao vamos colocar essas duas informacoes (nome, idade) e essas duas acoes (sentar e rolar) na nossa classe dog veremoa como criar uma classe a seguir

# %% [markdown]
# ### 9.1.1) criando classe dog

# %%
class dog:
    ''''Simples tentativa de domodelar um cachorro'''
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def sit(self):
        ''''simula um cachorro rolando em resposta a um comando'''
        print(f"{self.name} is now sitting")
    def roll_over(self):
        ''''Simula um cachorro rolando em resposta a um comando'''
        print(f"{self.name} is now roled over!")

# %% [markdown]
# Nao se assuste com essa estrutura. ao decorrer com esse capitulo irmaos ver essa estrutura e tera tempo de se acostumar. De inicio so saiba de quando usamos class chamada dog. por convenca a primeira letra e  ninuscula se refere as classes do python. A definicao de classes nao leva o parenteses pois estamos criando uma classe do zero. depois usamos dois pontos `:` para descrver o fim da classe.

# %% [markdown]
# ### 9.1.1) Metodo `__init__()`
